# %%
import pandas as pd

# %%
df = pd.read_csv("assets_df.csv", parse_dates=["date"], index_col="date")
obsdf = pd.read_csv("observations_df.csv", parse_dates=["date"], index_col="date")

# %%
df.head()
# Out:
#                      ZVQ_close  NCT_close  YAX_close  OOS_close  GFJ_close  \
# date
# 2018-12-19 01:00:00     519.23        0.0        0.0        0.0        0.0
# 2018-12-19 02:00:00     519.63        0.0        0.0        0.0        0.0
# 2018-12-19 03:00:00     519.95        0.0        0.0        0.0        0.0
# 2018-12-19 04:00:00     520.09        0.0        0.0        0.0        0.0
# 2018-12-19 05:00:00     520.06        0.0        0.0        0.0        0.0
#
#                      FIR_close  USX_close  FSK_close  TMF_close  TDD_close  \
# date
# 2018-12-19 01:00:00        0.0        0.0     154.69        0.0     116.07
# 2018-12-19 02:00:00        0.0        0.0     155.01        0.0     116.25
# 2018-12-19 03:00:00        0.0        0.0     155.08        0.0     116.45
# 2018-12-19 04:00:00        0.0        0.0     155.16        0.0     116.65
# 2018-12-19 05:00:00        0.0        0.0     155.23        0.0     116.30
#
# ...

# %%
df["YAX_close"].plot()
# Out:
# <AxesSubplot:xlabel='date'>
